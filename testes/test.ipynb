# %%
import psycopg2

def execute_sql_script(db_params, sql_file_path):
    # Conectar ao banco de dados
    try:
        conn = psycopg2.connect(**db_params)
        cursor = conn.cursor()
        
        # Ler o conteúdo do arquivo SQL
        with open(sql_file_path, 'r') as file:
            sql_script = file.read()
        
        # Executar o script SQL
        cursor.execute(sql_script)
        
        # Confirmar as alterações
        conn.commit()
        print("Script SQL executado com sucesso.")
    
    except Exception as e:
        print(f"Erro ao executar o script SQL: {e}")
    
    finally:
        # Fechar a conexão
        if cursor:
            cursor.close()
        if conn:
            conn.close()

# %%
import psycopg2
import random
import time
from datetime import datetime
import pytz

# Configurações de conexão com o banco de dados
HOST = "localhost"
PORT = 5432
USER = "admin"
PASSWORD = "admin"
DATABASE = "postgres"  # Substitua pelo nome do seu banco de dados

# Conecta ao banco de dados
conn = psycopg2.connect(
    host=HOST,
    port=PORT,
    user=USER,
    password=PASSWORD,
    dbname=DATABASE
)
cur = conn.cursor()

# Função para gerar e armazenar dados a cada 400 milissegundos
def gerar_e_armazenar_dados():
    tz = pytz.timezone('America/Sao_Paulo')  # Ajuste para o seu fuso horário local
    try:
        while True:
            timestamp = datetime.now().astimezone(tz)  # Converte para o fuso horário local
            temperatura = round(random.uniform(-10, 35), 2)  # Temperatura entre -10 e 35 graus Celsius
            umidade = round(random.uniform(0, 100), 2)  # Umidade entre 0 e 100%
            
            # Insere os dados nas tabelas
            cur.execute("INSERT INTO temperature (time, value) VALUES (%s, %s)", (timestamp, temperatura))
            cur.execute("INSERT INTO moisture (time, value) VALUES (%s, %s)", (timestamp, umidade))
            
            conn.commit()  # Confirma a transação
            
            time.sleep(1)  # Aguarda 400 milissegundos (0.4 segundos)
    except KeyboardInterrupt:
        print("Interrompido pelo usuário.")

# Gera e armazena dados continuamente
gerar_e_armazenar_dados()

# Fecha a conexão (não será alcançado a menos que o loop seja interrompido)
cur.close()
conn.close()
# Out:
# Interrompido pelo usuário.

# %% [markdown]
# ## MQTT

# %%
import paho.mqtt.client as mqtt
import psycopg2

# Configurações do banco de dados
DB_HOST = 'localhost'
DB_PORT = 5432
DB_NAME = 'postgres'
DB_USER = 'admin'
DB_PASSWORD = 'admin'

# Configurações do MQTT
MQTT_BROKER = 'www.maqiatto.com'
MQTT_PORT = 1883
MQTT_USER = 'lucasl050503@gmail.com'
MQTT_PASSWORD = '123456'

# Funções para o MQTT
def on_connect(client, userdata, flags, rc):
    print("Conectado com sucesso. Código de resultado:", rc)
    client.subscribe("lucasl050503@gmail.com/UPI1/moisture")
    client.subscribe("lucasl050503@gmail.com/UPI1/temperature")

def on_message(client, userdata, msg):
    print(f"Recebido mensagem em {msg.topic}: {msg.payload.decode()}")
    if msg.topic == "lucasl050503@gmail.com/UPI1/moisture":
        insert_data("moisture", msg.payload.decode())
    elif msg.topic == "lucasl050503@gmail.com/UPI1/temperature":
        insert_data("temperature", msg.payload.decode())

def insert_data(sensor_type, value):
    try:
        conn = psycopg2.connect(
            host=DB_HOST,
            port=DB_PORT,
            database=DB_NAME,
            user=DB_USER,
            password=DB_PASSWORD
        )
        cur = conn.cursor()
        if sensor_type == "moisture":
            cur.execute("INSERT INTO moisture_data (value) VALUES (%s)", (value,))
        elif sensor_type == "temperature":
            cur.execute("INSERT INTO temperature_data (value) VALUES (%s)", (value,))
        conn.commit()
        cur.close()
        conn.close()
    except Exception as e:
        print("Erro ao inserir dados:", e)

# Configuração do cliente MQTT
client = mqtt.Client()
client.username_pw_set(MQTT_USER, MQTT_PASSWORD)
client.on_connect = on_connect
client.on_message = on_message

# Conectar ao broker MQTT
client.connect(MQTT_BROKER, MQTT_PORT, 60)

# Loop para manter o cliente em execução
client.loop_forever()

# %%
import paho.mqtt.client as mqtt

MQTT_BROKER = 'www.maqiatto.com'
MQTT_PORT = 1883
MQTT_USER = 'lucasl050503@gmail.com'
MQTT_PASSWORD = '123456'


def on_connect(client, userdata, flags, rc):
    print("Conectado com sucesso. Código de resultado:", rc)
    client.subscribe("lucasl050503@gmail.com/UPI1/moisture")
    client.subscribe("lucasl050503@gmail.com/UPI1/temperature")

def on_message(client, userdata, msg):
    print(f"Recebido mensagem em {msg.topic}: {msg.payload.decode()}")


client = mqtt.Client()
client.username_pw_set(MQTT_USER, MQTT_PASSWORD)
client.on_connect = on_connect
client.on_message = on_message

client.connect(MQTT_BROKER, MQTT_PORT, 60)

client.loop_forever()
# Out:
# C:\Users\Warle\AppData\Local\Temp\ipykernel_14940\3933491529.py:18: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# Conectado com sucesso. Código de resultado: 0
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:45","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:46","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:47","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:48","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:49","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:50","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:51","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:53","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:54","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:55","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:56","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:57","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:58","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:42:59","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:00","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:01","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:02","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:03","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:04","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:05","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:06","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:07","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:08","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:09","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:10","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:11","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:12","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:13","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:14","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:15","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:16","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:17","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:18","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:19","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:20","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:21","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:22","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:23","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:24","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:25","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:26","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:27","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:28","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:29","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:30","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:32","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:33","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:34","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:35","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:36","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:37","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:38","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:39","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:40","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:41","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:42","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:43","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:44","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:45","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:46","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:47","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:48","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:49","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:50","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:51","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:52","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:53","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:54","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:55","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:56","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:57","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:58","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:43:59","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:00","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:01","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:02","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:03","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:04","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:05","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:06","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:07","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:08","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:10","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:11","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:12","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:13","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:14","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:15","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:16","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:17","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:20","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:21","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:22","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:23","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:24","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:25","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:26","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:27","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:29","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:30","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:31","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:32","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:33","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:34","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:35","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:36","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:37","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:38","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:39","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:40","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:41","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:42","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:43","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:44","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:45","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:46","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:47","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:48","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:49","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:51","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:52","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:53","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:54","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:55","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:56","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:57","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:44:59","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:01","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:02","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:03","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:04","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:05","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:06","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:07","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:08","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:09","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:10","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:11","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:12","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:13","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:14","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:15","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:16","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:17","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:18","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:19","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:20","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:21","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:22","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:23","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:24","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:25","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:26","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:27","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:28","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:29","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:30","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:31","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:32","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:33","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:36","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:37","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:38","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:39","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:40","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:41","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:42","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:43","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:44","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:45","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:46","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:47","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:48","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:49","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:50","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:51","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:52","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:53","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:54","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:55","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:56","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:57","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:45:59","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:00","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:01","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:02","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:03","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:04","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:05","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:06","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:07","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:08","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:09","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:10","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:11","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:12","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:13","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:14","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:15","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:16","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:17","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:18","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:19","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:20","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:22","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:23","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:24","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:25","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:26","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:27","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:28","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:29","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:30","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:31","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:32","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:33","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:34","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:35","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:36","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:37","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:38","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:39","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:40","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:42","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:43","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:44","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:45","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:46","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:47","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:48","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:49","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:50","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:51","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:52","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:53","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:54","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:55","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:56","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:57","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:58","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:46:59","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:00","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:01","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:02","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:03","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:04","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:05","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:06","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:07","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:08","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:09","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:10","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:11","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:12","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:13","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:14","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:15","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:16","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:17","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:18","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:20","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:21","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:22","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:23","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:24","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:25","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:26","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:27","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:28","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:29","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:30","value":24}
# Recebido mensagem em lucasl050503@gmail.com/UPI1/temperature: {"timestamp":"2024-07-29T12:47:31","value":24}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 25
#      21 client.on_message = on_message
#      23 client.connect(MQTT_BROKER, MQTT_PORT, 60)
# ---> 25 client.loop_forever()
#
# File c:\Users\Warle\anaconda3\envs\temp\Lib\site-packages\paho\mqtt\client.py:2297, in Client.loop_forever(self, timeout, retry_first_connection)
#    2295 rc = MQTTErrorCode.MQTT_ERR_SUCCESS
#    2296 while rc == MQTTErrorCode.MQTT_ERR_SUCCESS:
# -> 2297     rc = self._loop(timeout)
#    2298     # We don't need to worry about locking here, because we've
#    2299     # either called loop_forever() when in single threaded mode, or
#    2300     # in multi threaded mode when loop_stop() has been called and
#    2301     # so no other threads can access _out_packet or _messages.
#    2302     if (self._thread_terminate is True
#    2303         and len(self._out_packet) == 0
#    2304             and len(self._out_messages) == 0):
#
# File c:\Users\Warle\anaconda3\envs\temp\Lib\site-packages\paho\mqtt\client.py:1663, in Client._loop(self, timeout)
#    1660     rlist = [self._sock, self._sockpairR]
#    1662 try:
# -> 1663     socklist = select.select(rlist, wlist, [], timeout)
#    1664 except TypeError:
#    1665     # Socket isn't correct type, in likelihood connection is lost
#    1666     # ... or we called disconnect(). In that case the socket will
#    (...)
#    1669     # rc != MQTT_ERR_SUCCESS and we don't want state to change from
#    1670     # mqtt_cs_disconnecting.
#    1671     if self._state not in (_ConnectionState.MQTT_CS_DISCONNECTING, _ConnectionState.MQTT_CS_DISCONNECTED):
#
# KeyboardInterrupt:
